# %%
import pandas as pd
import numpy as np

df=pd.read_excel("/content/sample_data/ourdata.xlsx")
df.tail(10)
# Out:
#                 Name Class Use case                 Date Videos Count  \
# 399           waleed  face      NaN  2023-06-15 00:00:00            3
# 400        iqra khan  face      NaN  2023-06-16 00:00:00           23
# 401        iqra khan  face      NaN  2023-06-16 00:00:00            d
# 402     waleed ahmed  face      NaN  2023-06-19 00:00:00            5
# 403  Altamash Akhtar  face      NaN  2023-06-19 00:00:00           10
# 404  Altamash Akhtar  face      NaN  2023-06-20 00:00:00            5
# 405     waleed ahmed  face      NaN  2023-06-20 00:00:00            7
# 406      Naima Jamal  face      NaN  2023-06-20 00:00:00            2
# 407        iqra khan  face      NaN  2023-06-21 00:00:00            1
# 408      Naima Jamal  face      NaN  2023-06-21 00:00:00            5
#
#     Images Extracted  Images Annotated  Objects Annotated  Unnamed: 8  \
# 399              803             803.0              342.0         NaN
# ...

# %%
import pandas as pd
import numpy as np


dic1={

      'Name':['Muhammad','Altamash','Akhtar','Ahmed','Ali'],
      'University':['KU','IQ','INU','ND',np.nan],
      'Semester':[2,6,8,5,6],
      'Department':['Cs','Me','Ee','Ms','Ce'],
      'Off/On':['Yes','No','Yes','No','Yes']
}

a = pd.DataFrame(dic1)
a
# Out:
#        Name University  Semester Department Off/On
# 0  Muhammad         KU         2         Cs    Yes
# 1  Altamash         IQ         6         Me     No
# 2    Akhtar        INU         8         Ee    Yes
# 3     Ahmed         ND         5         Ms     No
# 4       Ali        NaN         6         Ce    Yes

# %%
a[['Name','University']]
# Out:
#        Name University
# 0  Muhammad         KU
# 1  Altamash         IQ
# 2    Akhtar        INU
# 3     Ahmed         ND
# 4       Ali        NaN

# %% [markdown]
# # New Section

# %%
a['Name']
# Out:
# 0    Muhammad
# 1    Altamash
# 2      Akhtar
# 3       Ahmed
# 4         Ali
# Name: Name, dtype: object

# %%
a[a.Semester>=6]
# Out:
#        Name University  Semester Department Off/On
# 1  Altamash         IQ         6         Me     No
# 2    Akhtar        INU         8         Ee    Yes
# 4       Ali        NaN         6         Ce    Yes

# %%
a[a.Name=='Altamash']
# Out:
#        Name University  Semester Department Off/On
# 1  Altamash         IQ         6         Me     No

# %%
a.set_index('University')
# Out:
#                 Name  Semester Off/On
# University
# KU          Muhammad         2    Yes
# IQ          Altamash         6     No
# INU           Akhtar         8    Yes
# ND             Ahmed         5     No
# NaN              Ali         6    Yes

# %%
import pandas as pd

a = pd.read_excel("sample_data/Data Annotation Activity Records (2).xlsx","Verification")
a.tail(10)
# Out:
#                 Name    Class  Person                 Date  Images Verified  \
# 112     waleed ahmed     face   usman  2023-06-13 00:00:00            984.0
# 113           waleed     face   usman  2023-06-15 00:00:00           1184.0
# 114            Usman   person   ammar  2023-06-15 00:00:00           1016.0
# 115  Altamash Akhtar   person   ammar  2023-06-15 00:00:00            597.0
# 116        iqra khan     face  waleed  2023-06-05 00:00:00            803.0
# 117     waleed ahmed     face   usman  2023-06-16 00:00:00            669.0
# 118     waleed ahmed     face    iqra  2023-06-19 00:00:00            958.0
# 119            Usman   person     NaN  2023-06-19 00:00:00           4120.0
# 120            Usman  vehicle  faizan  2023-06-20 00:00:00           1490.0
# 121            Usman  vehicle  faizan  2023-06-21 00:00:00            961.0
#
#      Objects Verified  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %% [markdown]
# # New Section

# %%
import pandas as pd

# Creating two list of tuples
data = [
    ('Ram', 'APPLE', 23),
    ('Shyam', 'GOOGLE', 25),
    ('Seeta', 'GOOGLE', 22),
    ('Geeta', 'MICROSOFT', 24),
    ('Raman', 'GOOGLE', 23),
    ('Sahil', 'SAMSUNG', 23)
]

# Creating a DataFrame
df = pd.DataFrame(data,columns=['Name','Company','Age'])
df
# Out:
#     Name    Company  Age
# 0    Ram      APPLE   23
# 1  Shyam     GOOGLE   25
# 2  Seeta     GOOGLE   22
# 3  Geeta  MICROSOFT   24
# 4  Raman     GOOGLE   23
# 5  Sahil    SAMSUNG   23

# %%
import pandas as pd

b= pd.read_csv("sample_data/california_housing_train.csv")
b
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
b= pd.read_csv("sample_data/california_housing_train.csv", skiprows=1)
b
# Out:
#        -114.310000  34.190000  15.000000  5612.000000  1283.000000  \
# 0          -114.47      34.40       19.0       7650.0       1901.0
# 1          -114.56      33.69       17.0        720.0        174.0
# 2          -114.57      33.64       14.0       1501.0        337.0
# 3          -114.57      33.57       20.0       1454.0        326.0
# 4          -114.58      33.63       29.0       1387.0        236.0
# ...            ...        ...        ...          ...          ...
# 16994      -124.26      40.58       52.0       2217.0        394.0
# 16995      -124.27      40.69       36.0       2349.0        528.0
# 16996      -124.30      41.84       17.0       2677.0        531.0
# 16997      -124.30      41.80       19.0       2672.0        552.0
# 16998      -124.35      40.54       52.0       1820.0        300.0
#
#        1015.000000  472.000000  1.493600  66900.000000
# 0           1129.0       463.0    1.8200       80100.0
# ...

# %%
import pandas as pd

c = pd.read_excel("sample_data/Data AnnotationDF.xlsx")
c
# Out:
#                Name                       Class  Use case       Date  \
# 0       Faizan Rauf                     vehicle       NaN 2023-06-02
# 1         iqra khan                        face       NaN 2023-06-05
# 2     Ammar Ibrahim                      person       NaN 2023-06-05
# 3    Farrukh Shakil                         NaN       NaN 2023-06-05
# 4       Faizan Rauf                     vehicle       NaN        NaT
# 5     Ammar Ibrahim                      person       NaN 2023-06-06
# 6      Waleed AHmed                      person       NaN 2023-06-05
# 7      Waleed Ahmed                      person       NaN 2023-06-06
# 8       Faizan Rauf                      person       NaN 2023-06-06
# 9       Faizan Rauf                      person       NaN 2023-06-07
# 10     Waleed Ahmed                     vehicle       NaN 2023-06-07
# 11     Waleed Ahmed                         NaN       NaN 2023-06-08
# 12        iqra khan                      person       NaN 2023-06-08
# ...

# %% [markdown]
# # ***GROUP BY ***

# %%
import pandas as pd

x=pd.read_excel("/content/weather.xlsx")
x
# Out:
#           Day     City   Temperature  Windspeed   Event
# 0  2017-01-01  New York           32          6    Rain
# 1  2017-01-02  New York           26          7   Sunny
# 2  2017-01-03  New York           28         12    Snow
# 3  2017-01-04  New York           33          7   Sunny
# 4  2017-01-01    Mumbai           90          5   Sunny
# 5  2017-01-02    Mumbai           85         12     Fog
# 6  2017-01-03    Mumbai           87         15     Fog
# 7  2017-01-04    Mumbai           92          5    Rain
# 8  2017-01-01     Paris           45         20   Sunny
# 9  2017-01-02     Paris           50         13  Cloudy
# 10 2017-01-03     Paris           54          8  Cloudy
# 11 2017-01-04     Paris           42         10  Cloudy

# %%
x
# Out:
#           Day     City   Temperature  Windspeed   Event
# 0  2017-01-01  New York           32          6    Rain
# 1  2017-01-02  New York           26          7   Sunny
# 2  2017-01-03  New York           28         12    Snow
# 3  2017-01-04  New York           33          7   Sunny
# 4  2017-01-01    Mumbai           90          5   Sunny
# 5  2017-01-02    Mumbai           85         12     Fog
# 6  2017-01-03    Mumbai           87         15     Fog
# 7  2017-01-04    Mumbai           92          5    Rain
# 8  2017-01-01     Paris           45         20   Sunny
# 9  2017-01-02     Paris           50         13  Cloudy
# 10 2017-01-03     Paris           54          8  Cloudy
# 11 2017-01-04     Paris           42         10  Cloudy

# %%
x.max()
# Out:
# Day            2017-01-04 00:00:00
# City                         Paris
# Temperature                     92
# Windspeed                       20
# Event                        Sunny
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-5ccaa7807aa4> in <cell line: 2>()
#       1 g= x
# ----> 2 g.get_group('mumbai')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'

# %%
x.mean()
# Out:
# <ipython-input-19-6f9184126d05>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   x.mean()
# <ipython-input-19-6f9184126d05>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x.mean()
# Temperature    55.333333
# Windspeed      10.000000
# dtype: float64

# %%
x.describe()
# Out:
#        Temperature  Windspeed
# count    12.000000  12.000000
# mean     55.333333  10.000000
# std      25.927638   4.572646
# min      26.000000   5.000000
# 25%      32.750000   6.750000
# 50%      47.500000   9.000000
# 75%      85.500000  12.250000
# max      92.000000  20.000000

# %%
# %matplotlib inline
x.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
pakistan_weather = pd.DataFrame({
    "city":["karachi","Lahore","Islamabad"],
    "temperature":[32,23,44],
    "humidity":[80,90,70]
})
pakistan_weather
# Out:
#         city  temperature  humidity
# 0    karachi           32        80
# 1     Lahore           23        90
# 2  Islamabad           44        70

# %%
india_weather = pd.DataFrame({
    "city":["mumbai","delhi","banglore"],
    "temperature":[12,32,50],
    "humidity":[50,88,100]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           12        50
# 1     delhi           32        88
# 2  banglore           50       100

# %%
# Out:
#        city  temperature  humidity
# 0    mumbai           12        50
# 1     delhi           32        88
# 2  banglore           50       100

# %%
w= pd.concat([pakistan_weather,india_weather], keys=["pakistan", "India"])
w
# Out:
#                  city  temperature  humidity
# pakistan 0    karachi           32        80
#          1     Lahore           23        90
#          2  Islamabad           44        70
# India    0     mumbai           12        50
#          1      delhi           32        88
#          2   banglore           50       100

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pakistan'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y, color='green',linewidth=5, linestyle='dotted')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('WEATHER')
# Out:
# Text(0.5, 1.0, 'WEATHER')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y,'g^')

# %%
plt.plot(x,y, color='green',alpha=0.2)

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,46,25]
avg_t=[45,48,48,46,40,41,42]

# %%
plt.plot(days,max_t, label="mAX")
plt.plot(days,min_t,label="Min")
plt.plot(days,avg_t, label="Avg")
plt.xlabel("DAYS")
plt.ylabel("Temperature")
plt.title("WEATHER")
plt.legend(loc="upper right")

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
company=['GOOGLE','AMAZON','MICROSOFT','FACEBOOK']
revenue=[90,136,89,50]
profit=[40,23,40,10]

# %%
ypos = np.arange(len(company))
ypos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(ypos,company)
plt.ylabel("REVENUE(bln)")
plt.xlabel("COMPANY")
plt.title("US TECH")
plt.bar(ypos,revenue, label="Revenue")
plt.bar(ypos,profit,label="profit")
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
blood_sugar_men=[113,85,90,150,149,88,93,115,135,80,77,82,129]
blood_sugar_women=[67,98,89,120,133,150,84,69,89,79,120,112,100]

plt.xlabel('sugar range')
plt.ylabel('Total no of patients')
plt.title('Bloo')
plt.hist([blood_sugar_men,blood_sugar_men], bins=[80,100,125,150], rwidth=0.95 , color=['green','orange'], label=['men','women'])
plt.legend()

# %%
import matplotlib.pyplot as plt

# Create the data
data = [10, 20, 30, 40]
labels = ["Label 1", "Label 2", "Label 3", "Label 4"]

# Create the pie chart
plt.pie(data, labels=labels,autopct='%0.1f%%',explode=[0.1,0.1,0,0])

# Add a title
plt.title("My Pie Chart")

# Show the pie chart
plt.show()
